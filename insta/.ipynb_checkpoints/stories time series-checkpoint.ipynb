# %% [markdown]
# # Stories

# %%
import numpy as np
import pandas as pd
import requests
import time
import matplotlib.pyplot as plt
import seaborn as sns
from pandasql import sqldf #for manipulating DataFrames with SQL style queries
#Write file to machine to work with offline
import json

#ALL BELOW to export results of API request to local file
# Make it work for Python 2+3 and with Unicode
import io
try:
    to_unicode = unicode
except NameError:
    to_unicode = str
    
from tqdm.autonotebook import tqdm

from datetime import datetime
# Out:
# /Users/ssrosa/anaconda3/lib/python3.7/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
df = pd.read_csv('stories_data.csv')

# %%
#Look at column descriptors for reference
df.head(1)
# Out:
#    story_id timestamp                                        exits  \
# 0       NaN       NaN  Number of times someone exited the carousel
#
#                                          impressions  \
# 0  Total number of times the media object has bee...
#
#                                                reach  \
# 0  Total number of unique accounts that have seen...
#
#                                    replies  \
# 0  Total number of replies to the carousel
#
#                                         taps_forward  \
# 0  Total number of taps to see this story's next ...
#
#                                            taps_back
# 0  Total number of taps to see this story's previ...

# %%
df.drop([0], axis = 0, inplace = True) #Drop column descriptors
df.set_index(pd.to_datetime(df['timestamp']), inplace = True)
df.drop(['timestamp', 'story_id'], axis = 1, inplace = True)
#Change remaining columns to int type
cols = ['exits', 'impressions', 'reach', 'replies', 'taps_forward', 'taps_back']
df[cols] = df[cols].astype(int)

# %%
df.head()
# Out:
#                      exits  impressions  reach  replies  taps_forward  \
# timestamp
# 2019-10-27 16:42:13      5          157    137        0            97
# 2019-10-27 16:43:55      7          127    115        0            88
# 2019-10-27 16:45:02      3          114    107        0            79
# 2019-10-27 16:46:08      2          113    103        0            92
# 2019-10-27 16:48:40      2          109    101        0            77
#
#                      taps_back
# timestamp
# 2019-10-27 16:42:13          4
# 2019-10-27 16:43:55          5
# 2019-10-27 16:45:02          4
# 2019-10-27 16:46:08          2
# 2019-10-27 16:48:40          5

# %% [markdown]
# # Stories October through December

# %%
df.plot(figsize = (16,10))

# %%
#hashtag_df = exploded[num_columns].groupby(['hashtags']).sum()

# %% [markdown]
# # By weekday

# %%
#df['weekday_num'] = df.index.weekday

# %%
weekdays
# Out:
#          exits  impressions  reach  replies  taps_forward  taps_back  hour  \
# weekday
# 0-Mon       99         2564   2318        3          1868         84   361
# 1-Tue       39          648    595        0           417         15    59
# 2-Wed       79         1817   1694        0          1324         43   354
# 3-Thu      112         2563   2362        1          1948         62   476
# 4-Fri      107         3329   3148        1          2615         86   647
# 5-Sat       68         1922   1812        0          1489         40   444
# 6-Sun       81         1669   1487        0          1023         42   238
#
#          weekday_num
# weekday
# 0-Mon              0
# 1-Tue             10
# 2-Wed             42
# 3-Thu             87
# 4-Fri            152
# 5-Sat            120
# 6-Sun             90

# %%
#Add a weekday column
df['weekday'] = df.index.strftime('%w-%a')
#Now sum up data into weekdays
weekdays = df.groupby(['weekday']).sum()
weekdays['story_count'] = df['weekday'].value_counts()
#Divide each column by its number of stories to get the mean
weekday_means = pd.DataFrame({col: weekdays[col] / weekdays['story_count'] for col in cols})

# %%
weekday_means
# Out:
#             exits  impressions       reach   replies  taps_forward  taps_back
# weekday
# 0-Sun    5.400000   111.266667   99.133333  0.000000     68.200000   2.800000
# 1-Mon    4.500000   116.545455  105.363636  0.136364     84.909091   3.818182
# 2-Tue    3.900000    64.800000   59.500000  0.000000     41.700000   1.500000
# 3-Wed    3.761905    86.523810   80.666667  0.000000     63.047619   2.047619
# 4-Thu    3.862069    88.379310   81.448276  0.034483     67.172414   2.137931
# 5-Fri    2.815789    87.605263   82.842105  0.026316     68.815789   2.263158
# 6-Sat    2.833333    80.083333   75.500000  0.000000     62.041667   1.666667

# %%
#weekday_means.plot(figsize = (12,8))
fig = plt.figure(figsize = (12,8))
plt.plot(weekday_means)
plt.xticks(weekday_means.index)
plt.title('Average values by weekday')
# Out:
# Text(0.5,1,'Average values by weekday')

# %%
#Add an hours column
df['hour'] = df.index.strftime('%w%-H %-I%p %a')
df['hour_day'] =  df['weekday'].astype(str) + '-' + df['hour'].astype(str)
#Now sum up data into hour-days
hour_days = df.groupby(['hour_day']).sum()
hour_days['story_count'] = df['hour_day'].value_counts()
#Divide each column by its number of stories to get the mean
hour_days_means = pd.DataFrame({col: hour_days[col] / hour_days['story_count'] for col in cols})
hour_days_means.plot(figsize = (16,10))
plt.title('Average values by hour of the day')
# Out:
# Text(0.5,1,'Average values by hour of the day')

# %%
fig = plt.figure(figsize = (16,8))
plt.plot(hour_days_means)
plt.xticks(hour_days_means.index)
plt.title('Average values by hour')
# Out:
# Text(0.5,1,'Average values by hour')

# %% [markdown]
# # RESUME HERE. Resolve ticks. Check DH thing.
#
# # strftime columns work but aren't clearest for labeling.
